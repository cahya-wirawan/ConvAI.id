# %% [markdown]
# <a href="https://colab.research.google.com/github/cahya-wirawan/ConvAI.id/blob/main/Machine_Translation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture

# !pip install transformers
# !pip install sentencepiece

# %%
from tqdm import tqdm
from collections import Counter
from pathlib import Path
import re
from transformers import MarianMTModel, MarianTokenizer
import torch

# %%
class Translation():
    def __init__(self, model_name):
        self.device = "cuda" if torch.cuda.is_available() else "cpu"
        self.tokenizer = MarianTokenizer.from_pretrained(model_name)
        self.model = MarianMTModel.from_pretrained(model_name).cuda()

    def translate(self, source_text):
        inputs = self.tokenizer(source_text, return_tensors="pt", padding=True).to(self.device)
        translated = self.model.generate(**inputs)
        translation = [self.tokenizer.decode(t, skip_special_tokens=True) for t in translated]
        return translation

# %%
model_name = "Wikidepia/marian-nmt-enid"
translator = Translation(model_name)
# Out:
# Downloading:   0%|          | 0.00/211 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/780k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/780k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/737k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/992 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/147M [00:00<?, ?B/s]

# %%
sentences = [
             "I am hungry, but I don't have money to buy food",
             "My friend goes to school every morning with bus"
]

# %%
translator.translate(sentences)
# Out:
# ['Saya lapar, tetapi saya tidak punya uang untuk membeli makanan',
#  'Teman saya pergi ke sekolah setiap pagi dengan bus']
